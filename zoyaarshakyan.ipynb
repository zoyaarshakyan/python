# %%
import pandas as pd
list1=[pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/01/17-30"),pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/02/17-30"),pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/03/17-30"),pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/04/17-30"),pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/05/17-30"),pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/06/17-30"),pd.read_html("http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/07/17-30")]
for rates in list1:
    print rates[2][2:19]
# Out:
#      0                       1    2   3              4       5       6   \
# 2    1.               Արցախբանկ  NaN  24  01 Հնս, 17:30     481  484.50
# 3    2.               Ինեկոբանկ  NaN  23  01 Հնս, 17:30  480.50  483.75
# 4    3.       ՎՏԲ-Հայաստան Բանկ  NaN  68  01 Հնս, 17:30  480.75  483.25
# 5    4.             Մելլաթ բանկ  NaN   1  01 Հնս, 17:30     480     484
# 6    5.       Էյչ-Էս-Բի-Սի Բանկ  NaN   9  01 Հնս, 17:30  480.50  484.50
# 7    6.            Կոնվերս բանկ  NaN  35  01 Հնս, 17:30     480  483.50
# 8    7.  ԱԿԲԱ-ԿՐԵԴԻՏ ԱԳՐԻԿՈԼ ..  NaN  59  01 Հնս, 17:30  480.25  483.75
# 9    8.       ՀԱՅԲԻԶՆԵՍԲԱՆԿ ՓԲԸ  NaN  53  01 Հնս, 17:30     480  483.50
# 10   9.              Ամերիաբանկ  NaN  11  01 Հնս, 17:30  479.50  483.50
# 11  10.           ՀԱՅԷԿՈՆՈՄԲԱՆԿ  NaN  49  01 Հնս, 17:30     480  483.50
# 12  11.             Արմսվիսբանկ  NaN   1  01 Հնս, 17:30     481     484
# 13  12.              Արդշինբանկ  NaN  53  01 Հնս, 17:30  480.50  483.50
# ...

# %%
import re
import requests
url1="https://www.bloomberg.com/quote/SPX:IND"
link = requests.get(url1)
data = link.text
data1 = re.sub(r'<|>'," ",data)
output=re.findall('"price"\s*([0-9]\S*)',data1)
print output
# Out:
# [u'2,429.39']

# %%
import json
input='''[
    {
    "Movie":"Game of Thrones",
    "Actor":"Peter Dinklage",
    "Role":"Tyrion Lannister"    
    },
    {
    "Movie":"Vikings",
    "Actor":"Travis Fimmel",
    "Role":"Ragnar Lothbrok"  
    },
    {
    "Movie":"The last Kingdom",
    "Actor":{
            "Young Uhtred":"Tom Taylor",
            "Not that young Uhtred":"Alexander Dreymon"
            },
    "Role":"Uhtred of Bebbanburg"
    }
]'''
inpt=json.loads(input)
for x in inpt:
        print"Movie:", x['Movie']
        print "Role:", x["Role"]
        if type(x["Actor"]) == dict:
                print "Actor 1: " , x["Actor"]['Young Uhtred']
                print "Actor 2: " , x["Actor"]['Not that young Uhtred']
        else:
            print "Actor:", x["Actor"], "\n"
# Out:
# Movie: Game of Thrones
# Role: Tyrion Lannister
# Actor: Peter Dinklage
#
# Movie: Vikings
# Role: Ragnar Lothbrok
# Actor: Travis Fimmel
#
# Movie: The last Kingdom
# Role: Uhtred of Bebbanburg
# Actor 1:  Tom Taylor
# Actor 2:  Alexander Dreymon

# %%
import pandas as pd
import matplotlib.pyplot as plt
pcsv=pd.read_csv("AirPassengers.csv")
pcsv1=pcsv.Passengers
print pcsv1
plt.plot(pcsv.Passengers)
plt.show()
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
# 5      135
# 6      148
# 7      148
# 8      136
# 9      119
# 10     104
# 11     118
# 12     115
# 13     126
# 14     141
# 15     135
# 16     125
# 17     149
# 18     170
# 19     170
# 20     158
# 21     133
# 22     114
# 23     140
# 24     145
# 25     150
# 26     178
# 27     163
# 28     172
# 29     178
#       ...
# 114    491
# 115    505
# 116    404
# 117    359
# 118    310
# 119    337
# 120    360
# 121    342
# 122    406
# 123    396
# 124    420
# 125    472
# 126    548
# 127    559
# 128    463
# 129    407
# 130    362
# 131    405
# 132    417
# 133    391
# 134    419
# 135    461
# 136    472
# 137    535
# 138    622
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: Passengers, dtype: int64

# %%
import re
import requests
url="http://quotes.toscrape.com/"
link = requests.get(url)
pg=link.text
pg1=re.findall('<a href\s*="\S+"\s*>Next', pg)
pg2=re.sub(r'^(.*?)/'," http://quotes.toscrape.com/",str(pg1))
pg3=re.sub(r'">Next'," ",pg2)
print pg3
# Out:
#  http://quotes.toscrape.com/page/2/ ']
